# %%
import numpy as np

# Generate random data
np.random.seed(42)
x = np.random.rand(100)
y = np.random.rand(100)
z = np.random.rand(100)

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')

# Scatter plot
ax.scatter(x, y, z, c='b', marker='o', label='Data Points')

# Customize labels
ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')
ax.set_zlabel('Z-axis')
ax.set_title('Conditional Probability 3D Plot')

plt.show()

# %% [markdown]
# # Performing on breast cancer

# %%
# Generate random data (replace with actual data)
np.random.seed(42)
x = np.random.rand(100)  # X coordinates
y = np.random.rand(100)  # Y coordinates
z = np.random.rand(100)  # Z coordinates (depth or altitude)

# %%
# Create a 3D scatter plot
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')

# Scatter plot
ax.scatter(x, y, z, c='b', marker='o', label='Breast Cancer Data Points')

# Customize labels
ax.set_xlabel('X-axis (Feature 1)')
ax.set_ylabel('Y-axis (Feature 2)')
ax.set_zlabel('Z-axis (Feature 3)')
ax.set_title('3D Scatter Plot of Breast Cancer Data')

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_breast_cancer

# Load the breast cancer dataset
cancer = load_breast_cancer()

# Create a DataFrame with features and target
data = pd.DataFrame(cancer.data, columns=cancer.feature_names)
data['target'] = cancer.target

# Plot feature distributions
plt.figure(figsize=(12, 6))
for feature in cancer.feature_names:
    plt.plot(data[feature], label=feature)

plt.xlabel('Sample Index')
plt.ylabel('Feature Value')
plt.title('Distribution of Breast Cancer Features')
plt.legend()
plt.show()

# %%
import seaborn as sns
from sklearn.datasets import load_iris

# %%
#load the iris datasets
iris = load_iris()
data = iris.data
target = iris.target

# %%
#create a dataframe from iris data
df = pd.DataFrame(data,columns=iris.feature_names)
df['target'] = target

# %%
#use seaborn to create a pairplot
sns.pairplot(df,hue='target')
